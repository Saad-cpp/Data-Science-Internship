# %% [markdown]
# <a href="https://colab.research.google.com/github/Saad-cpp/Data-Science-Internship/blob/main/texttosql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
gem_key = userdata.get('GEMINI-KEY')

# %%
# !pip install google-generativeai

# %%
import sqlite3
import google.generativeai as genai

# %%
conn = sqlite3.connect("mydb.db")

# %%
cur = conn.cursor()

# %%
query = """Create table STUDENTS(
Name varchar(255) not null primary key,
Class varchar(50) not null,
Section char(1) not null,
Grade_percentage int not null)"""

# %%
cur.execute(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-62e23c8ecbae> in <cell line: 1>()
# ----> 1 cur.execute(query)
#
# OperationalError: table STUDENTS already exists

# %%
query = """Insert into STUDENTS values
('Saad', 'Data Science', 'A', 96),
('Ali', 'Web Development', 'A', 92),
('Sara', 'Machine Learning', 'A', 88),
('Zara', 'Machine Learning', 'A', 94),
('Omar', 'Machine Learning', 'B', 85),
('Lina', 'Web Development', 'A', 90),
('Tariq', 'Web Development', 'A', 93),
('Aisha', 'Web Development', 'B', 81),
('Bilal', 'Data Science', 'A', 95),
('Fatima', 'Data Science', 'B', 89),
('Khalid', 'Data Science', 'A', 91),
('Nida', 'Data Science', 'A', 97)
"""

# %%
cur.execute(query)

# %%
query = "Select * from STUDENTS"
rows = cur.execute(query)
for row in rows:
    print(row)
# Out:
# ('Saad', 'Data Science', 'A', 96)
# ('Ali', 'Web Development', 'A', 92)
# ('Sara', 'Machine Learning', 'A', 88)
# ('Zara', 'Machine Learning', 'A', 94)
# ('Omar', 'Machine Learning', 'B', 85)
# ('Lina', 'Web Development', 'A', 90)
# ('Tariq', 'Web Development', 'A', 93)
# ('Aisha', 'Web Development', 'B', 81)
# ('Bilal', 'Data Science', 'A', 95)
# ('Fatima', 'Data Science', 'B', 89)
# ('Khalid', 'Data Science', 'A', 91)
# ('Nida', 'Data Science', 'A', 97)

# %%
conn.commit()

# %%
genai.configure(api_key=gem_key)
def get_model_response(question, prompt):
    model = genai.GenerativeModel("gemini-pro")
    response = model.generate_content([prompt[0], question])
    return response.text

# %%
def read_sql_query(sql, db):
    conn = sqlite3.connect(db)
    cur = conn.cursor()
    cur.execute(sql)
    rows = cur.fetchall()
    conn.commit()
    conn.close()
    for row in rows:
        print(row)
    return rows

# %%
prompt=[
    """
    You are an expert in converting English questions to SQL query!
    The SQL database has the name STUDENTS and has the following columns - NAME, CLASS,
    SECTION, GRADE_PERCENTAGE \n\nFor example,\nExample 1 - How many entries of records are present?,
    the SQL command will be something like this SELECT COUNT(*) FROM STUDENTS ;
    \nExample 2 - Tell me all the students studying in Data Science class?,
    the SQL command will be something like this SELECT * FROM STUDENTS
    where CLASS="Data Science";
    also the sql code should not have ``` in beginning or end and sql word in output

    """


]

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 50.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 13.1
#     Uninstalling websockets-13.1:
#       Successfully uninstalled websockets-13.1
# ...

# %%
import gradio as gr

# %%
def gradio_function(question):
    sql_query = get_model_response(question, prompt)
    print(sql_query)
    result = read_sql_query(sql_query, "mydb.db")
    return result

# %%
ui = gr.Interface(fn=gradio_function, inputs="text", outputs="text", title="Text to SQL Query", description="Enter a question and get the corresponding SQL query.")

# %%
ui.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://48a68d3d58d3a84758.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://48a68d3d58d3a84758.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# SELECT NAME FROM STUDENTS ORDER BY NAME ASC;
# ('Aisha',)
# ('Ali',)
# ('Bilal',)
# ('Fatima',)
# ('Khalid',)
# ('Lina',)
# ('Nida',)
# ('Omar',)
# ('Saad',)
# ('Sara',)
# ('Tariq',)
# ('Zara',)
# SELECT COUNT(*) FROM STUDENTS;
# (12,)
# ...
